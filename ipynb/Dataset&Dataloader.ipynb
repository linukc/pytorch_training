# %% [markdown]
# #1. [PyTorch Tutorial 09 - Dataset and DataLoader - Batch Training](https://www.youtube.com/watch?v=PXOzkkB5eH0)

# %% [markdown]
# epoch = 1 forward and backward pass of ALL training samples
#
# batch_size = number of training samples in one forward and backward pass
#
# number of iterations = number of passes, each pass using [batch_size] number of samples
#
# e.g. 100 samples, batch_size=20 --> 100/20 = 5 iterations for 1 epoch

# %%
import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np
import math

# %%
#dataset available in google colab sample_data folder
class CaliforniaHousingDataset(Dataset):
  def __init__(self):
    # potential memory risks - do load in the getitem method (e.g keep only references to the files location for images)
    xy = np.loadtxt('./sample_data/california_housing_test.csv', delimiter=',', dtype=np.float32, skiprows=1)
    self.x = torch.from_numpy(xy[:, :-1])
    self.y = torch.from_numpy(xy[:, [-1]])
    self.n_samples = xy.shape[0]
  
  def __getitem__(self, index):
    return self.x[index], self.y[index]

  def __len__(self):
    return self.n_samples

# %%
dataset = CaliforniaHousingDataset()
features, labels = dataset[0]
features, labels
# Out:
# (tensor([-122.0500,   37.3700,   27.0000, 3885.0000,  661.0000, 1537.0000,
#           606.0000,    6.6085]), tensor(344700.))

# %%
#datasampler?
dataloader = DataLoader(dataset=dataset, batch_size=2, shuffle=True, num_workers=2)

# %%
dataiter = iter(dataloader)
data = dataiter.next()
features, labels = data
features, labels
# Out:
# (tensor([[-1.2132e+02,  3.8620e+01,  2.9000e+01,  2.4300e+03,  4.4800e+02,
#            1.0870e+03,  3.9400e+02,  3.0864e+00],
#          [-1.1729e+02,  3.4490e+01,  3.0000e+00,  7.6890e+03,  1.5450e+03,
#            3.8040e+03,  1.3990e+03,  3.3871e+00]]), tensor([177900., 111800.]))

# %%
# dummy training loop
num_epochs = 2
total_samples = len(dataset)
n_iterations = math.ceil(total_samples / 2)
total_samples, n_iterations
# Out:
# (3000, 1500)

# %%
for epoch in range(num_epochs):
  for i, (inputs, labels) in enumerate(dataloader):
    #forward, backward, update
    if (i+1) % 5 == 0:
      print(f'epoch {epoch+1}/{num_epochs}, step {i+1}/{n_iterations}, inputs {inputs.shape}')
# Out:
# epoch 1/2, step 5/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 10/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 15/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 20/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 25/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 30/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 35/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 40/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 45/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 50/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 55/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 60/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 65/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 70/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 75/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 80/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 85/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 90/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 95/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 100/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 105/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 110/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 115/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 120/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 125/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 130/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 135/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 140/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 145/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 150/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 155/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 160/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 165/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 170/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 175/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 180/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 185/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 190/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 195/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 200/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 205/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 210/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 215/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 220/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 225/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 230/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 235/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 240/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 245/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 250/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 255/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 260/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 265/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 270/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 275/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 280/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 285/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 290/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 295/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 300/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 305/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 310/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 315/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 320/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 325/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 330/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 335/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 340/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 345/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 350/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 355/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 360/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 365/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 370/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 375/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 380/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 385/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 390/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 395/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 400/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 405/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 410/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 415/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 420/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 425/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 430/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 435/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 440/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 445/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 450/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 455/1500, inputs torch.Size([2, 8])
# epoch 1/2, step 460/1500, inputs torch.Size([2, 8])
# epoch 1/2, step
1500, inputs torch.Size([2, 8])
# epoch 2/2, step 705/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 710/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 715/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 720/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 725/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 730/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 735/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 740/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 745/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 750/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 755/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 760/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 765/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 770/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 775/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 780/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 785/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 790/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 795/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 800/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 805/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 810/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 815/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 820/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 825/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 830/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 835/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 840/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 845/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 850/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 855/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 860/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 865/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 870/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 875/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 880/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 885/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 890/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 895/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 900/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 905/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 910/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 915/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 920/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 925/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 930/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 935/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 940/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 945/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 950/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 955/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 960/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 965/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 970/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 975/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 980/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 985/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 990/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 995/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1000/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1005/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1010/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1015/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1020/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1025/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1030/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1035/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1040/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1045/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1050/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1055/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1060/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1065/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1070/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1075/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1080/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1085/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1090/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1095/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1100/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1105/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1110/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1115/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1120/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1125/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1130/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1135/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1140/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1145/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1150/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1155/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1160/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1165/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1170/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1175/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1180/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1185/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1190/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1195/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1200/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1205/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1210/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1215/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1220/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1225/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1230/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1235/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1240/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1245/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1250/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1255/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1260/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1265/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1270/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1275/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1280/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1285/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1290/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1295/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1300/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1305/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1310/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1315/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1320/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1325/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1330/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1335/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1340/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1345/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1350/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1355/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1360/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1365/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1370/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1375/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1380/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1385/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1390/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1395/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1400/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1405/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1410/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1415/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1420/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1425/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1430/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1435/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1440/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1445/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1450/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1455/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1460/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1465/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1470/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1475/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1480/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1485/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1490/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1495/1500, inputs torch.Size([2, 8])
# epoch 2/2, step 1500/1500, inputs torch.Size([2, 8])

# %%
from torchvision.datasets import ...

# %% [markdown]
# # 2. [PyTorch Tutorial 10 - Dataset Transforms](https://www.youtube.com/watch?v=X_QOZEko5uE&list=PLqnslRFeH2UrcDBWF5mfPGpqQDSta6VK4&index=10)

# %%
class CaliforniaHousingDataset(Dataset):
  def __init__(self, transform=None):
    # potential memory risks - do load in the getitem method (e.g keep only references to the files location for images)
    xy = np.loadtxt('./sample_data/california_housing_test.csv', delimiter=',', dtype=np.float32, skiprows=1)
    self.x = xy[:, :-1]
    self.y = xy[:, [-1]]
    self.n_samples = xy.shape[0]

    self.transform = transform

  def __getitem__(self, index):
    sample = self.x[index], self.y[index]
    if self.transform:
      sample = self.transform(sample)
    
    return sample

  def __len__(self):
    return self.n_samples

# %%
#custom to tensor transform
class ToTensor():
  def __call__(self, sample):
    inputs, targets = sample
    return torch.from_numpy(inputs), torch.from_numpy(targets)

# %%
dataset = CaliforniaHousingDataset(transform=ToTensor())

# %%
first_data = dataset[0]
inputs, labels = first_data
type(inputs), type(labels)
# Out:
# (torch.Tensor, torch.Tensor)

# %%
class MulTransform():
  def __init__(self, factor):
    self.factor = factor

  def __call__(self, sample):
    inputs, target = sample
    inputs*= self.factor
    return inputs, target

# %%
composed = torchvision.transforms.Compose([ToTensor(), MulTransform(2)])
dataset = CaliforniaHousingDataset(transform=composed)

# %%
first_data = dataset[0]
inputs, labels = first_data
type(inputs), type(labels)
# Out:
# (torch.Tensor, torch.Tensor)
